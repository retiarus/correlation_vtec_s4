# %% [markdown]
# # Preprocessamento S4
# ___
#
# Este notebook realiza um pré-processamento dos dados de S4 disponibilizados em data_s4. O preprocessamento consiste de uma conversão de indices para tratamento de séries temporais, uma reamostragem para amostras de 1s (nos dados orginais, o número de medidas a cada segundo, dependendo do número de satélites visíveis, porém, em geral é mais que um), interpolaçãos spline, seguido de suavização com um kernel gaussiano com janela de tamanho 25, seguindo como uma reamostragem para dados a cada 10 mim, e uma suavização usando um kernel gausiano de janela 25.

# %%
import os
import re
import sys

import pathos.multiprocessing as mulprocessing
import pandas as pd

from functools import partial
from scipy.signal import savgol_filter
from pathos.multiprocessing import ProcessPool

import utils
from utils import local_data, local_s4, local_s4_pre
from utils import window

# %%
df_station = pd.read_pickle(os.path.join(local_data, 'df_station_sort.pkl'))

# %%
files = os.listdir(local_s4)

# %%
print(files)
# Out:
# ['df_1.pkl.xz', 'df_11.pkl.xz', 'df_14.pkl.xz', 'df_15.pkl.xz', 'df_16.pkl.xz', 'df_17.pkl.xz', 'df_18.pkl.xz', 'df_19.pkl.xz', 'df_20.pkl.xz', 'df_22.pkl.xz', 'df_24.pkl.xz', 'df_25.pkl.xz', 'df_26.pkl.xz', 'df_28.pkl.xz', 'df_29.pkl.xz', 'df_3.pkl.xz', 'df_30.pkl.xz', 'df_31.pkl.xz', 'df_32.pkl.xz', 'df_33.pkl.xz', 'df_34.pkl.xz', 'df_4.pkl.xz', 'df_5.pkl.xz', 'df_6.pkl.xz', 'df_8.pkl.xz', 'df_afl.pkl.xz', 'df_bhz.pkl.xz', 'df_bov.pkl.xz', 'df_bsa.pkl.xz', 'df_cpa.pkl.xz', 'df_cub.pkl.xz', 'df_dou.pkl.xz', 'df_imp.pkl.xz', 'df_ios.pkl.xz', 'df_nta.pkl.xz', 'df_pln.pkl.xz', 'df_pvh.pkl.xz', 'df_sj2.pkl.xz', 'df_sta.pkl.xz', 'df_tfe.pkl.xz']

# %% [markdown]
# Inicialmente, os dados de S4 são tais que existe mais de uma amostra por minuto, decorrente dos múltiplos satélites de GPS que estavam no campo de visada da estão naquele intervalo.
#
# O primeiro passo, assim, é combinar as várias medidas no intervalo de minuto gerando uma única medida por minuto, neste caso, tomou-se o valor m?dio de todos as medidas neste intervalo.
#
# O segundo passo é tratar as entradas sem valores, aqui, decidiu-se por utilizar uma interpolação por spline de ordem 3.
#
# O terceiro passo foi uma reamostragem dos dados para intervalores de 10 minutos, de forma, a compatibilizar com as taxas de amostragem dos demais dados a serem utilizados como o VTEC.
#
# Segue-se então como uma suavização do sinal, por meio de uma aplicação de uma média móvel centrada com pesos gaussianos. Note, uma vez que trata-se de uma m?dia centrada:
#
# \begin{equation}
# y_t = \sum_{i=-n}^{+n}w_iy_{t+i}
# \end{equation}
#
# onde $n$  a srepresenta o tamanho da janela. A suavização definiada, assim, leva em conta pontos futuros, tornando-a inadequada para aplicações em tempo real, pontos no futuro não são conhecidos, e em previsões de séries temporais, a suavização adiciona contribuição do futuro aos dados.

# %%
def preprocessing(df_file, window):
    df_s4 = pd.read_pickle(os.path.join(local_s4, df_file), compression='xz')
    df_s4['eventdate'] = pd.to_datetime(df_s4['eventdate'], utc=True)
    df_s4.index = df_s4['eventdate']
    del df_s4['eventdate']
    
    # change for 1s
    df_s4 = df_s4.resample('1T').mean()
    df_s4 = df_s4.interpolate(method='spline', order=4) #4

    # change for 10min
    df_s4 = df_s4.resample('10T').mean()

    # aplay filter Savitzky-Golay
    # aplay a gaussian move average
    df_s4['s4'] = savgol_filter(df_s4.values.ravel(), window, 3)
    df_s4 = df_s4.rolling(window, win_type='gaussian', center=True).mean(std=1.0)
    
    return df_s4

preprocessing_window = partial(preprocessing, window=window)

# %%
# %%time
df_s4_list = ProcessPool(nodes=mulprocessing.cpu_count()).map(preprocessing_window, files)
# Out:
# CPU times: user 153 ms, sys: 49.9 ms, total: 203 ms
# Wall time: 2min 19s

# %%
for name, df_s4 in zip(files, df_s4_list):
    df_s4.to_pickle(os.path.join(local_s4_pre,'pre_' + name.replace('.xz', '')))

# %% [markdown]
# Contenar os dados de S4 pré-processados.

# %%
stations = [i.identificationstation for i in df_station.itertuples()]

# %%
def df_list(list_stations, local): 
    for i in list_stations:
        path = local + '/' + 'pre_df_%s.pkl' %i
        df_s4 = pd.read_pickle(path)
        #pattern = re.compile(local + "/" + "pre_df_(.*)\.pkl")
        #name = pattern.sub(r'\1', i)
        yield df_s4.rename(index=str, columns={"s4": i})
        
df_combine = partial(df_list, list_stations=stations, local=local_s4_pre)

df_s4 = pd.concat(df_combine(), axis=1, sort=True)

# %%
print(df_s4.shape)
df_s4.head()
# Out:
# (105132, 28)
#                                afl  bhz      bov  bsa       cpa  32       cub  \
# 2013-01-01 00:00:00+00:00      NaN  NaN      NaN  NaN       NaN NaN       NaN
# 2013-01-01 00:10:00+00:00      NaN  NaN      NaN  NaN       NaN NaN       NaN
# 2013-01-01 00:20:00+00:00      NaN  NaN      NaN  NaN       NaN NaN       NaN
# 2013-01-01 00:30:00+00:00      NaN  NaN      NaN  NaN       NaN NaN       NaN
# 2013-01-01 00:40:00+00:00  0.20636  NaN  0.29408  NaN  0.223676 NaN  0.189246
#
#                                 dou  24  34 ...   pln  30   4  pvh   6  26  \
# 2013-01-01 00:00:00+00:00       NaN NaN NaN ...   NaN NaN NaN  NaN NaN NaN
# 2013-01-01 00:10:00+00:00       NaN NaN NaN ...   NaN NaN NaN  NaN NaN NaN
# 2013-01-01 00:20:00+00:00       NaN NaN NaN ...   NaN NaN NaN  NaN NaN NaN
# 2013-01-01 00:30:00+00:00       NaN NaN NaN ...   NaN NaN NaN  NaN NaN NaN
# 2013-01-01 00:40:00+00:00  0.207889 NaN NaN ...   NaN NaN NaN  NaN NaN NaN
#
#                                 sta  sj2  29  tfe
# 2013-01-01 00:00:00+00:00       NaN  NaN NaN  NaN
# 2013-01-01 00:10:00+00:00       NaN  NaN NaN  NaN
# 2013-01-01 00:20:00+00:00       NaN  NaN NaN  NaN
# 2013-01-01 00:30:00+00:00       NaN  NaN NaN  NaN
# 2013-01-01 00:40:00+00:00  0.208724  NaN NaN  NaN
#
# [5 rows x 28 columns]

# %%
df_s4.index = pd.to_datetime(df_s4.index)

# %%
df_s4.to_pickle(os.path.join(local_data, 'df_series_s4.pkl.xz'), compression='xz')

# %%
df_s4
# Out:
#                           afl  bhz       bov  bsa       cpa  32       cub  \
# 2013-01-01 00:00:00       NaN  NaN       NaN  NaN       NaN NaN       NaN
# 2013-01-01 00:10:00       NaN  NaN       NaN  NaN       NaN NaN       NaN
# 2013-01-01 00:20:00       NaN  NaN       NaN  NaN       NaN NaN       NaN
# 2013-01-01 00:30:00       NaN  NaN       NaN  NaN       NaN NaN       NaN
# 2013-01-01 00:40:00  0.206360  NaN  0.294080  NaN  0.223676 NaN  0.189246
# 2013-01-01 00:50:00  0.204201  NaN  0.291502  NaN  0.247244 NaN  0.203963
# 2013-01-01 01:00:00  0.199353  NaN  0.284655  NaN  0.277687 NaN  0.215993
# 2013-01-01 01:10:00  0.193080  NaN  0.274296  NaN  0.304045 NaN  0.221741
# 2013-01-01 01:20:00  0.187098  NaN  0.264138  NaN  0.318292 NaN  0.219275
# 2013-01-01 01:30:00  0.182627  NaN  0.253925  NaN  0.321141 NaN  0.209468
# 2013-01-01 01:40:00  0.181267  NaN  0.240974  NaN  0.317191 NaN  0.197955
# 2013-01-01 01:50:00  0.186004  NaN  0.225776  NaN  0.303740 NaN  0.192614
# 2013-01-01 02:00:00  0.196145  NaN  0.211591  NaN  0.283741 NaN  0.195943
# 2013-01-01 02:10:00  0.207574  NaN  0.200376  NaN  0.266224 NaN  0.204289
# 2013-01-01 02:20:00  0.216526  NaN  0.190632  NaN  0.251892 NaN  0.213850
# 2013-01-01 02:30:00  0.219379  NaN  0.181234  NaN  0.242835 NaN  0.221864
# 2013-01-01 02:40:00  0.214678  NaN  0.175059  NaN  0.239283 NaN  0.224705
# 2013-01-01 02:50:00  0.204915  NaN  0.172319  NaN  0.242764 NaN  0.220241
# 2013-01-01 03:00:00  0.193522  NaN  0.169992  NaN  0.254081 NaN  0.210612
# 2013-01-01 03:10:00  0.182716  NaN  0.166531  NaN  0.265961 NaN  0.199987
# 2013-01-01 03:20:00  0.172866  NaN  0.162804  NaN  0.271549 NaN  0.189144
# 2013-01-01 03:30:00  0.164897  NaN  0.159726  NaN  0.269889 NaN  0.177635
# 2013-01-01 03:40:00  0.160807  NaN  0.158273  NaN  0.261882 NaN  0.167193
# 2013-01-01 03:50:00  0.162677  NaN  0.160031  NaN  0.249605 NaN  0.160590
# 2013-01-01 04:00:00  0.170467  NaN  0.164907  NaN  0.233431 NaN  0.158639
# 2013-01-01 04:10:00  0.181799  NaN  0.171249  NaN  0.217967 NaN  0.158520
# 2013-01-01 04:20:00  0.190968  NaN  0.177522  NaN  0.209215 NaN  0.157725
# 2013-01-01 04:30:00  0.193785  NaN  0.181347  NaN  0.204158 NaN  0.155824
# 2013-01-01 04:40:00  0.189492  NaN  0.180669  NaN  0.197786 NaN  0.153294
# 2013-01-01 04:50:00  0.179553  NaN  0.175728  NaN  0.189526 NaN  0.149593
# ...                       ...  ...       ...  ...       ...  ..       ...
# 2014-12-31 21:00:00       NaN  NaN       NaN  NaN       NaN NaN       NaN
# 2014-12-31 21:10:00       NaN  NaN       NaN  NaN       NaN NaN       NaN
# 2014-12-31 21:20:00       NaN  NaN       NaN  NaN       NaN NaN       NaN
# 2014-12-31 21:30:00       NaN  NaN       NaN  NaN       NaN NaN       NaN
# 2014-12-31 21:40:00       NaN  NaN       NaN  NaN       NaN NaN       NaN
# 2014-12-31 21:50:00       NaN  NaN       NaN  NaN       NaN NaN       NaN
# 2014-12-31 22:00:00       NaN  NaN       NaN  NaN       NaN NaN       NaN
# 2014-12-31 22:10:00       NaN  NaN       NaN  NaN       NaN NaN       NaN
# 2014-12-31 22:20:00       NaN  NaN       NaN  NaN       NaN NaN       NaN
# 2014-12-31 22:30:00       NaN  NaN       NaN  NaN       NaN NaN       NaN
# 2014-12-31 22:40:00       NaN  NaN       NaN  NaN       NaN NaN       NaN
# 2014-12-31 22:50:00       NaN  NaN       NaN  NaN       NaN NaN       NaN
# 2014-12-31 23:00:00       NaN  NaN       NaN  NaN       NaN NaN       NaN
# 2014-12-31 23:10:00       NaN  NaN       NaN  NaN       NaN NaN       NaN
# 2014-12-31 23:20:00       NaN  NaN       NaN  NaN       NaN NaN       NaN
# 2014-12-31 23:30:00       NaN  NaN       NaN  NaN       NaN NaN       NaN
# 2014-12-31 23:40:00       NaN  NaN       NaN  NaN       NaN NaN       NaN
# 2014-12-31 23:50:00       NaN  NaN       NaN  NaN       NaN NaN       NaN
# 2015-01-01 00:00:00       NaN  NaN       NaN  NaN       NaN NaN       NaN
# 2015-01-01 00:10:00       NaN  NaN       NaN  NaN       NaN NaN       NaN
# 2015-01-01 00:20:00       NaN  NaN       NaN  NaN       NaN NaN       NaN
# 2015-01-01 00:30:00       NaN  NaN       NaN  NaN       NaN NaN       NaN
# 2015-01-01 00:40:00       NaN  NaN       NaN  NaN       NaN NaN       NaN
# 2015-01-01 00:50:00       NaN  NaN       NaN  NaN       NaN NaN       NaN
# 2015-01-01 01:00:00       NaN  NaN       NaN  NaN       NaN NaN       NaN
# 2015-01-01 01:10:00       NaN  NaN       NaN  NaN       NaN NaN       NaN
# 2015-01-01 01:20:00       NaN  NaN       NaN  NaN       NaN NaN       NaN
# 2015-01-01 01:30:00       NaN  NaN       NaN  NaN       NaN NaN       NaN
# 2015-01-01 01:40:00       NaN  NaN       NaN  NaN       NaN NaN       NaN
# 2015-01-01 01:50:00       NaN  NaN       NaN  NaN       NaN NaN       NaN
#
#                           dou        24  34 ...   pln  30         4  pvh  \
# 2013-01-01 00:00:00       NaN       NaN NaN ...   NaN NaN       NaN  NaN
# 2013-01-01 00:10:00       NaN       NaN NaN ...   NaN NaN       NaN  NaN
# 2013-01-01 00:20:00       NaN       NaN NaN ...   NaN NaN       NaN  NaN
# 2013-01-01 00:30:00       NaN       NaN NaN ...   NaN NaN       NaN  NaN
# 2013-01-01 00:40:00  0.207889       NaN NaN ...   NaN NaN       NaN  NaN
# 2013-01-01 00:50:00  0.215338       NaN NaN ...   NaN NaN       NaN  NaN
# 2013-01-01 01:00:00  0.224347       NaN NaN ...   NaN NaN       NaN  NaN
# 2013-01-01 01:10:00  0.234827       NaN NaN ...   NaN NaN       NaN  NaN
# 2013-01-01 01:20:00  0.241238       NaN NaN ...   NaN NaN       NaN  NaN
# 2013-01-01 01:30:00  0.239972       NaN NaN ...   NaN NaN       NaN  NaN
# 2013-01-01 01:40:00  0.234776       NaN NaN ...   NaN NaN       NaN  NaN
# 2013-01-01 01:50:00  0.230325       NaN NaN ...   NaN NaN       NaN  NaN
# 2013-01-01 02:00:00  0.227217       NaN NaN ...   NaN NaN       NaN  NaN
# 2013-01-01 02:10:00  0.225503       NaN NaN ...   NaN NaN       NaN  NaN
# 2013-01-01 02:20:00  0.227649       NaN NaN ...   NaN NaN       NaN  NaN
# 2013-01-01 02:30:00  0.234406       NaN NaN ...   NaN NaN       NaN  NaN
# 2013-01-01 02:40:00  0.243260       NaN NaN ...   NaN NaN  0.140995  NaN
# 2013-01-01 02:50:00  0.251036       NaN NaN ...   NaN NaN  0.138893  NaN
# 2013-01-01 03:00:00  0.253654       NaN NaN ...   NaN NaN  0.138333  NaN
# 2013-01-01 03:10:00  0.250939       NaN NaN ...   NaN NaN  0.138819  NaN
# 2013-01-01 03:20:00  0.245964       NaN NaN ...   NaN NaN  0.141223  NaN
# 2013-01-01 03:30:00  0.242904       NaN NaN ...   NaN NaN  0.145134  NaN
# 2013-01-01 03:40:00  0.244512       NaN NaN ...   NaN NaN  0.147429  NaN
# 2013-01-01 03:50:00  0.248275       NaN NaN ...   NaN NaN  0.146279  NaN
# 2013-01-01 04:00:00  0.249727       NaN NaN ...   NaN NaN  0.142745  NaN
# 2013-01-01 04:10:00  0.244125       NaN NaN ...   NaN NaN  0.140222  NaN
# 2013-01-01 04:20:00  0.228358       NaN NaN ...   NaN NaN  0.140435  NaN
# 2013-01-01 04:30:00  0.207014       NaN NaN ...   NaN NaN  0.142496  NaN
# 2013-01-01 04:40:00  0.187482       NaN NaN ...   NaN NaN  0.145560  NaN
# 2013-01-01 04:50:00  0.174649       NaN NaN ...   NaN NaN  0.147873  NaN
# ...                       ...       ...  .. ...   ...  ..       ...  ...
# 2014-12-31 21:00:00       NaN  0.134239 NaN ...   NaN NaN  0.121632  NaN
# 2014-12-31 21:10:00       NaN  0.133682 NaN ...   NaN NaN  0.117402  NaN
# 2014-12-31 21:20:00       NaN  0.133510 NaN ...   NaN NaN  0.114011  NaN
# 2014-12-31 21:30:00       NaN  0.133710 NaN ...   NaN NaN  0.111316  NaN
# 2014-12-31 21:40:00       NaN  0.134868 NaN ...   NaN NaN  0.110108  NaN
# 2014-12-31 21:50:00       NaN  0.137329 NaN ...   NaN NaN  0.110151  NaN
# 2014-12-31 22:00:00       NaN  0.139952 NaN ...   NaN NaN  0.109755  NaN
# 2014-12-31 22:10:00       NaN  0.141428 NaN ...   NaN NaN  0.107984  NaN
# 2014-12-31 22:20:00       NaN  0.140938 NaN ...   NaN NaN  0.105586  NaN
# 2014-12-31 22:30:00       NaN  0.138565 NaN ...   NaN NaN  0.103925  NaN
# 2014-12-31 22:40:00       NaN  0.135092 NaN ...   NaN NaN  0.103120  NaN
# 2014-12-31 22:50:00       NaN  0.131664 NaN ...   NaN NaN  0.102135  NaN
# 2014-12-31 23:00:00       NaN  0.129695 NaN ...   NaN NaN  0.101675  NaN
# 2014-12-31 23:10:00       NaN  0.129745 NaN ...   NaN NaN  0.102724  NaN
# 2014-12-31 23:20:00       NaN  0.131841 NaN ...   NaN NaN  0.104923  NaN
# 2014-12-31 23:30:00       NaN  0.135473 NaN ...   NaN NaN  0.107965  NaN
# 2014-12-31 23:40:00       NaN  0.138632 NaN ...   NaN NaN  0.111372  NaN
# 2014-12-31 23:50:00       NaN  0.139028 NaN ...   NaN NaN  0.114249  NaN
# 2015-01-01 00:00:00       NaN  0.136093 NaN ...   NaN NaN  0.115734  NaN
# 2015-01-01 00:10:00       NaN  0.132234 NaN ...   NaN NaN  0.115984  NaN
# 2015-01-01 00:20:00       NaN  0.131511 NaN ...   NaN NaN  0.115282  NaN
# 2015-01-01 00:30:00       NaN  0.136183 NaN ...   NaN NaN  0.113257  NaN
# 2015-01-01 00:40:00       NaN  0.147683 NaN ...   NaN NaN  0.110471  NaN
# 2015-01-01 00:50:00       NaN  0.166382 NaN ...   NaN NaN  0.109069  NaN
# 2015-01-01 01:00:00       NaN  0.188816 NaN ...   NaN NaN  0.110955  NaN
# 2015-01-01 01:10:00       NaN  0.209155 NaN ...   NaN NaN  0.117019  NaN
# 2015-01-01 01:20:00       NaN       NaN NaN ...   NaN NaN       NaN  NaN
# 2015-01-01 01:30:00       NaN       NaN NaN ...   NaN NaN       NaN  NaN
# 2015-01-01 01:40:00       NaN       NaN NaN ...   NaN NaN       NaN  NaN
# 2015-01-01 01:50:00       NaN       NaN NaN ...   NaN NaN       NaN  NaN
#
#                             6  26       sta  sj2  29  tfe
# 2013-01-01 00:00:00       NaN NaN       NaN  NaN NaN  NaN
# 2013-01-01 00:10:00       NaN NaN       NaN  NaN NaN  NaN
# 2013-01-01 00:20:00       NaN NaN       NaN  NaN NaN  NaN
# 2013-01-01 00:30:00       NaN NaN       NaN  NaN NaN  NaN
# 2013-01-01 00:40:00       NaN NaN  0.208724  NaN NaN  NaN
# 2013-01-01 00:50:00       NaN NaN  0.205463  NaN NaN  NaN
# 2013-01-01 01:00:00       NaN NaN  0.194973  NaN NaN  NaN
# 2013-01-01 01:10:00       NaN NaN  0.182419  NaN NaN  NaN
# 2013-01-01 01:20:00       NaN NaN  0.175116  NaN NaN  NaN
# 2013-01-01 01:30:00       NaN NaN  0.178336  NaN NaN  NaN
# 2013-01-01 01:40:00       NaN NaN  0.188436  NaN NaN  NaN
# 2013-01-01 01:50:00       NaN NaN  0.195912  NaN NaN  NaN
# 2013-01-01 02:00:00       NaN NaN  0.201445  NaN NaN  NaN
# 2013-01-01 02:10:00       NaN NaN  0.208433  NaN NaN  NaN
# 2013-01-01 02:20:00       NaN NaN  0.213256  NaN NaN  NaN
# 2013-01-01 02:30:00       NaN NaN  0.213588  NaN NaN  NaN
# 2013-01-01 02:40:00  0.191347 NaN  0.209748  NaN NaN  NaN
# 2013-01-01 02:50:00  0.205121 NaN  0.202540  NaN NaN  NaN
# 2013-01-01 03:00:00  0.212125 NaN  0.193262  NaN NaN  NaN
# 2013-01-01 03:10:00  0.212708 NaN  0.186218  NaN NaN  NaN
# 2013-01-01 03:20:00  0.210955 NaN  0.188016  NaN NaN  NaN
# 2013-01-01 03:30:00  0.212134 NaN  0.197310  NaN NaN  NaN
# 2013-01-01 03:40:00  0.218847 NaN  0.204654  NaN NaN  NaN
# 2013-01-01 03:50:00  0.230157 NaN  0.204448  NaN NaN  NaN
# 2013-01-01 04:00:00  0.240820 NaN  0.195556  NaN NaN  NaN
# 2013-01-01 04:10:00  0.246065 NaN  0.180608  NaN NaN  NaN
# 2013-01-01 04:20:00  0.244574 NaN  0.164512  NaN NaN  NaN
# 2013-01-01 04:30:00  0.236701 NaN  0.151324  NaN NaN  NaN
# 2013-01-01 04:40:00  0.225346 NaN  0.143602  NaN NaN  NaN
# 2013-01-01 04:50:00  0.214057 NaN  0.140678  NaN NaN  NaN
# ...                       ...  ..       ...  ...  ..  ...
# 2014-12-31 21:00:00  0.146126 NaN       NaN  NaN NaN  NaN
# 2014-12-31 21:10:00  0.146515 NaN       NaN  NaN NaN  NaN
# 2014-12-31 21:20:00  0.145681 NaN       NaN  NaN NaN  NaN
# 2014-12-31 21:30:00  0.144199 NaN       NaN  NaN NaN  NaN
# 2014-12-31 21:40:00  0.142198 NaN       NaN  NaN NaN  NaN
# 2014-12-31 21:50:00  0.139461 NaN       NaN  NaN NaN  NaN
# 2014-12-31 22:00:00  0.135370 NaN       NaN  NaN NaN  NaN
# 2014-12-31 22:10:00  0.131191 NaN       NaN  NaN NaN  NaN
# 2014-12-31 22:20:00  0.129455 NaN       NaN  NaN NaN  NaN
# 2014-12-31 22:30:00  0.130076 NaN       NaN  NaN NaN  NaN
# 2014-12-31 22:40:00  0.131385 NaN       NaN  NaN NaN  NaN
# 2014-12-31 22:50:00  0.132196 NaN       NaN  NaN NaN  NaN
# 2014-12-31 23:00:00  0.132156 NaN       NaN  NaN NaN  NaN
# 2014-12-31 23:10:00  0.130595 NaN       NaN  NaN NaN  NaN
# 2014-12-31 23:20:00  0.126903 NaN       NaN  NaN NaN  NaN
# 2014-12-31 23:30:00  0.122835 NaN       NaN  NaN NaN  NaN
# 2014-12-31 23:40:00  0.121557 NaN       NaN  NaN NaN  NaN
# 2014-12-31 23:50:00  0.123453 NaN       NaN  NaN NaN  NaN
# 2015-01-01 00:00:00  0.126225 NaN       NaN  NaN NaN  NaN
# 2015-01-01 00:10:00  0.127891 NaN       NaN  NaN NaN  NaN
# 2015-01-01 00:20:00  0.128133 NaN       NaN  NaN NaN  NaN
# 2015-01-01 00:30:00  0.128070 NaN       NaN  NaN NaN  NaN
# 2015-01-01 00:40:00  0.128770 NaN       NaN  NaN NaN  NaN
# 2015-01-01 00:50:00  0.130103 NaN       NaN  NaN NaN  NaN
# 2015-01-01 01:00:00  0.134401 NaN       NaN  NaN NaN  NaN
# 2015-01-01 01:10:00  0.146474 NaN       NaN  NaN NaN  NaN
# 2015-01-01 01:20:00       NaN NaN       NaN  NaN NaN  NaN
# 2015-01-01 01:30:00       NaN NaN       NaN  NaN NaN  NaN
# 2015-01-01 01:40:00       NaN NaN       NaN  NaN NaN  NaN
# 2015-01-01 01:50:00       NaN NaN       NaN  NaN NaN  NaN
#
# [105132 rows x 28 columns]
