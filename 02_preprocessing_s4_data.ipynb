# %% [markdown]
# # Preprocessamento S4
# ___
#
# Este notebook realiza um pré-processamento dos dados de S4 disponibilizados em data_s4. O preprocessamento consiste de uma conversão de indices para tratamento de séries temporais, uma reamostragem para amostras de 1s (nos dados orginais, o número de medidas a cada segundo, dependendo do número de satélites visíveis, porém, em geral é mais que um), interpolaçãos spline, seguido de suavização com um kernel gaussiano com janela de tamanho 25, seguindo como uma reamostragem para dados a cada 10 mim, e uma suavização usando um kernel gausiano de janela 25.

# %%
import os
import re
import sys

import pathos.multiprocessing as mulprocessing
import numpy as np
import pandas as pd

from functools import partial
from scipy.signal import savgol_filter
from pathos.multiprocessing import ProcessPool

import utils
from utils import local_data, local_s4, local_s4_pre
from utils import window

# %%
df_station = pd.read_pickle(os.path.join(local_data, 'df_station_sort.pkl'))

# %%
files = os.listdir(local_s4)

# %%
print(files)
# Out:
# ['df_1.pkl.xz', 'df_11.pkl.xz', 'df_14.pkl.xz', 'df_15.pkl.xz', 'df_16.pkl.xz', 'df_17.pkl.xz', 'df_18.pkl.xz', 'df_19.pkl.xz', 'df_20.pkl.xz', 'df_22.pkl.xz', 'df_24.pkl.xz', 'df_25.pkl.xz', 'df_26.pkl.xz', 'df_28.pkl.xz', 'df_29.pkl.xz', 'df_3.pkl.xz', 'df_30.pkl.xz', 'df_31.pkl.xz', 'df_32.pkl.xz', 'df_33.pkl.xz', 'df_34.pkl.xz', 'df_4.pkl.xz', 'df_5.pkl.xz', 'df_6.pkl.xz', 'df_8.pkl.xz', 'df_afl.pkl.xz', 'df_bhz.pkl.xz', 'df_bov.pkl.xz', 'df_bsa.pkl.xz', 'df_cpa.pkl.xz', 'df_cub.pkl.xz', 'df_dou.pkl.xz', 'df_imp.pkl.xz', 'df_ios.pkl.xz', 'df_nta.pkl.xz', 'df_pln.pkl.xz', 'df_pvh.pkl.xz', 'df_sj2.pkl.xz', 'df_sta.pkl.xz', 'df_tfe.pkl.xz']

# %% [markdown]
# Inicialmente, os dados de S4 são tais que existe mais de uma amostra por minuto, decorrente dos múltiplos satélites de GPS que estavam no campo de visada da estão naquele intervalo.
#
# O primeiro passo, assim, é combinar as várias medidas no intervalo de minuto gerando uma única medida por minuto, neste caso, tomou-se o valor m?dio de todos as medidas neste intervalo.
#
# O segundo passo é tratar as entradas sem valores, aqui, decidiu-se por utilizar uma interpolação por spline de ordem 3.
#
# O terceiro passo foi uma reamostragem dos dados para intervalores de 10 minutos, de forma, a compatibilizar com as taxas de amostragem dos demais dados a serem utilizados como o VTEC.
#
# Segue-se então como uma suavização do sinal, por meio de uma aplicação de uma média móvel centrada com pesos gaussianos. Note, uma vez que trata-se de uma m?dia centrada:
#
# \begin{equation}
# y_t = \sum_{i=-n}^{+n}w_iy_{t+i}
# \end{equation}
#
# onde $n$  a srepresenta o tamanho da janela. A suavização definiada, assim, leva em conta pontos futuros, tornando-a inadequada para aplicações em tempo real, pontos no futuro não são conhecidos, e em previsões de séries temporais, a suavização adiciona contribuição do futuro aos dados.

# %%
def preprocessing(df_file, window):
    df_s4 = pd.read_pickle(os.path.join(local_s4, df_file), compression='xz')
    df_s4['eventdate'] = pd.to_datetime(df_s4['eventdate'], utc=True)
    df_s4.index = df_s4['eventdate']
    del df_s4['eventdate']
    
    # change s4 by its vertical projection, drop elevation
    df_s4['s4'] = df_s4.s4*(np.sin(df_s4.elevation*2*np.pi/360))**0.9
    del df_s4['elevation']
    
    # change for 1s
    df_s4 = df_s4.resample('1T').mean()
    df_s4 = df_s4.interpolate(method='spline', order=4) #4

    # change for 10min
    df_s4 = df_s4.resample('10T').mean()

    # aplay filter Savitzky-Golay
    # aplay a gaussian move average
    df_s4['s4'] = savgol_filter(df_s4.values.ravel(), window, 3)
    df_s4 = df_s4.rolling(window, win_type='gaussian', center=True).mean(std=1.0)
    
    return df_s4

preprocessing_window = partial(preprocessing, window=window)

# %%
# %%time
df_s4_list = ProcessPool(nodes=mulprocessing.cpu_count()).map(preprocessing_window, files)
# Out:
# /var/lib/jupyterhub/anaconda/envs/dscience/lib/python3.6/site-packages/scipy/signal/_arraytools.py:45: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   b = a[a_slice]
# /var/lib/jupyterhub/anaconda/envs/dscience/lib/python3.6/site-packages/scipy/signal/_arraytools.py:45: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   b = a[a_slice]
# /var/lib/jupyterhub/anaconda/envs/dscience/lib/python3.6/site-packages/scipy/signal/_arraytools.py:45: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   b = a[a_slice]
# /var/lib/jupyterhub/anaconda/envs/dscience/lib/python3.6/site-packages/scipy/signal/_arraytools.py:45: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   b = a[a_slice]
# /var/lib/jupyterhub/anaconda/envs/dscience/lib/python3.6/site-packages/scipy/signal/_arraytools.py:45: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   b = a[a_slice]
# /var/lib/jupyterhub/anaconda/envs/dscience/lib/python3.6/site-packages/scipy/signal/_arraytools.py:45: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   b = a[a_slice]
# /var/lib/jupyterhub/anaconda/envs/dscience/lib/python3.6/site-packages/scipy/signal/_arraytools.py:45: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   b = a[a_slice]
# /var/lib/jupyterhub/anaconda/envs/dscience/lib/python3.6/site-packages/scipy/signal/_arraytools.py:45: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   b = a[a_slice]
# /var/lib/jupyterhub/anaconda/envs/dscience/lib/python3.6/site-packages/scipy/signal/_arraytools.py:45: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   b = a[a_slice]
# /var/lib/jupyterhub/anaconda/envs/dscience/lib/python3.6/site-packages/scipy/signal/_arraytools.py:45: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   b = a[a_slice]
# /var/lib/jupyterhub/anaconda/envs/dscience/lib/python3.6/site-packages/scipy/signal/_arraytools.py:45: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   b = a[a_slice]
# /var/lib/jupyterhub/anaconda/envs/dscience/lib/python3.6/site-packages/scipy/signal/_arraytools.py:45: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   b = a[a_slice]
# /var/lib/jupyterhub/anaconda/envs/dscience/lib/python3.6/site-packages/scipy/signal/_arraytools.py:45: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   b = a[a_slice]
# /var/lib/jupyterhub/anaconda/envs/dscience/lib/python3.6/site-packages/scipy/signal/_arraytools.py:45: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   b = a[a_slice]
# /var/lib/jupyterhub/anaconda/envs/dscience/lib/python3.6/site-packages/scipy/signal/_arraytools.py:45: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   b = a[a_slice]
# /var/lib/jupyterhub/anaconda/envs/dscience/lib/python3.6/site-packages/scipy/signal/_arraytools.py:45: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   b = a[a_slice]
# /var/lib/jupyterhub/anaconda/envs/dscience/lib/python3.6/site-packages/scipy/signal/_arraytools.py:45: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   b = a[a_slice]
# /var/lib/jupyterhub/anaconda/envs/dscience/lib/python3.6/site-packages/scipy/signal/_arraytools.py:45: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   b = a[a_slice]
# /var/lib/jupyterhub/anaconda/envs/dscience/lib/python3.6/site-packages/scipy/signal/_arraytools.py:45: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   b = a[a_slice]
# /var/lib/jupyterhub/anaconda/envs/dscience/lib/python3.6/site-packages/scipy/signal/_arraytools.py:45: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   b = a[a_slice]
# /var/lib/jupyterhub/anaconda/envs/dscience/lib/python3.6/site-packages/scipy/signal/_arraytools.py:45: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   b = a[a_slice]
# /var/lib/jupyterhub/anaconda/envs/dscience/lib/python3.6/site-packages/scipy/signal/_arraytools.py:45: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   b = a[a_slice]
# /var/lib/jupyterhub/anaconda/envs/dscience/lib/python3.6/site-packages/scipy/signal/_arraytools.py:45: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   b = a[a_slice]
# /var/lib/jupyterhub/anaconda/envs/dscience/lib/python3.6/site-packages/scipy/signal/_arraytools.py:45: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   b = a[a_slice]
# /var/lib/jupyterhub/anaconda/envs/dscience/lib/python3.6/site-packages/scipy/signal/_arraytools.py:45: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   b = a[a_slice]
# /var/lib/jupyterhub/anaconda/envs/dscience/lib/python3.6/site-packages/scipy/signal/_arraytools.py:45: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   b = a[a_slice]
# /var/lib/jupyterhub/anaconda/envs/dscience/lib/python3.6/site-packages/scipy/signal/_arraytools.py:45: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   b = a[a_slice]
# /var/lib/jupyterhub/anaconda/envs/dscience/lib/python3.6/site-packages/scipy/signal/_arraytools.py:45: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   b = a[a_slice]
# /var/lib/jupyterhub/anaconda/envs/dscience/lib/python3.6/site-packages/scipy/signal/_arraytools.py:45: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   b = a[a_slice]
# /var/lib/jupyterhub/anaconda/envs/dscience/lib/python3.6/site-packages/scipy/signal/_arraytools.py:45: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   b = a[a_slice]
# /var/lib/jupyterhub/anaconda/envs/dscience/lib/python3.6/site-packages/scipy/signal/_arraytools.py:45: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   b = a[a_slice]
# /var/lib/jupyterhub/anaconda/envs/dscience/lib/python3.6/site-packages/scipy/signal/_arraytools.py:45: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   b = a[a_slice]
# /var/lib/jupyterhub/anaconda/envs/dscience/lib/python3.6/site-packages/scipy/signal/_arraytools.py:45: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   b = a[a_slice]
# /var/lib/jupyterhub/anaconda/envs/dscience/lib/python3.6/site-packages/scipy/signal/_arraytools.py:45: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   b = a[a_slice]
# /var/lib/jupyterhub/anaconda/envs/dscience/lib/python3.6/site-packages/scipy/signal/_arraytools.py:45: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   b = a[a_slice]
# /var/lib/jupyterhub/anaconda/envs/dscience/lib/python3.6/site-packages/scipy/signal/_arraytools.py:45: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   b = a[a_slice]
# /var/lib/jupyterhub/anaconda/envs/dscience/lib/python3.6/site-packages/scipy/signal/_arraytools.py:45: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   b = a[a_slice]
# /var/lib/jupyterhub/anaconda/envs/dscience/lib/python3.6/site-packages/scipy/signal/_arraytools.py:45: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   b = a[a_slice]
# /var/lib/jupyterhub/anaconda/envs/dscience/lib/python3.6/site-packages/scipy/signal/_arraytools.py:45: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   b = a[a_slice]
# /var/lib/jupyterhub/anaconda/envs/dscience/lib/python3.6/site-packages/scipy/signal/_arraytools.py:45: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   b = a[a_slice]
# CPU times: user 131 ms, sys: 95 ms, total: 226 ms
# Wall time: 1min 20s

# %%
for name, df_s4 in zip(files, df_s4_list):
    df_s4.to_pickle(os.path.join(local_s4_pre,'pre_' + name.replace('.xz', '')))

# %% [markdown]
# Contenar os dados de S4 pré-processados.

# %%
stations = [i.identificationstation for i in df_station.itertuples()]

# %%
def df_list(list_stations, local): 
    for i in list_stations:
        path = local + '/' + 'pre_df_%s.pkl' %i
        df_s4 = pd.read_pickle(path)
        #pattern = re.compile(local + "/" + "pre_df_(.*)\.pkl")
        #name = pattern.sub(r'\1', i)
        yield df_s4.rename(index=str, columns={"s4": i})
        
df_combine = partial(df_list, list_stations=stations, local=local_s4_pre)

df_s4 = pd.concat(df_combine(), axis=1, sort=True)

# %%
print(df_s4.shape)
df_s4.head()
# Out:
# (105132, 28)
#                            afl  bhz  bov  bsa       cpa  32       cub  dou  \
# 2013-01-01 00:00:00+00:00  NaN  NaN  NaN  NaN       NaN NaN       NaN  NaN
# 2013-01-01 00:10:00+00:00  NaN  NaN  NaN  NaN       NaN NaN       NaN  NaN
# 2013-01-01 00:20:00+00:00  NaN  NaN  NaN  NaN       NaN NaN       NaN  NaN
# 2013-01-01 00:30:00+00:00  NaN  NaN  NaN  NaN       NaN NaN       NaN  NaN
# 2013-01-01 00:40:00+00:00  NaN  NaN  NaN  NaN  0.137439 NaN  0.110996  NaN
#
#                            24  33 ...   30   4  pvh   6  34  26  sta  sj2  29  \
# 2013-01-01 00:00:00+00:00 NaN NaN ...  NaN NaN  NaN NaN NaN NaN  NaN  NaN NaN
# 2013-01-01 00:10:00+00:00 NaN NaN ...  NaN NaN  NaN NaN NaN NaN  NaN  NaN NaN
# 2013-01-01 00:20:00+00:00 NaN NaN ...  NaN NaN  NaN NaN NaN NaN  NaN  NaN NaN
# 2013-01-01 00:30:00+00:00 NaN NaN ...  NaN NaN  NaN NaN NaN NaN  NaN  NaN NaN
# 2013-01-01 00:40:00+00:00 NaN NaN ...  NaN NaN  NaN NaN NaN NaN  NaN  NaN NaN
#
#                            tfe
# 2013-01-01 00:00:00+00:00  NaN
# 2013-01-01 00:10:00+00:00  NaN
# 2013-01-01 00:20:00+00:00  NaN
# 2013-01-01 00:30:00+00:00  NaN
# 2013-01-01 00:40:00+00:00  NaN
#
# [5 rows x 28 columns]

# %%
df_s4.index = pd.to_datetime(df_s4.index)

# %%
df_s4.to_pickle(os.path.join(local_data, 'df_series_s4.pkl.xz'), compression='xz')

# %%
df_s4
# Out:
#                      afl  bhz  bov  bsa       cpa  32       cub  dou  \
# 2013-01-01 00:00:00  NaN  NaN  NaN  NaN       NaN NaN       NaN  NaN
# 2013-01-01 00:10:00  NaN  NaN  NaN  NaN       NaN NaN       NaN  NaN
# 2013-01-01 00:20:00  NaN  NaN  NaN  NaN       NaN NaN       NaN  NaN
# 2013-01-01 00:30:00  NaN  NaN  NaN  NaN       NaN NaN       NaN  NaN
# 2013-01-01 00:40:00  NaN  NaN  NaN  NaN  0.137439 NaN  0.110996  NaN
# 2013-01-01 00:50:00  NaN  NaN  NaN  NaN  0.125193 NaN  0.109120  NaN
# 2013-01-01 01:00:00  NaN  NaN  NaN  NaN  0.121766 NaN  0.109498  NaN
# 2013-01-01 01:10:00  NaN  NaN  NaN  NaN  0.135663 NaN  0.110651  NaN
# 2013-01-01 01:20:00  NaN  NaN  NaN  NaN  0.159211 NaN  0.111184  NaN
# 2013-01-01 01:30:00  NaN  NaN  NaN  NaN  0.176146 NaN  0.110674  NaN
# 2013-01-01 01:40:00  NaN  NaN  NaN  NaN  0.179651 NaN  0.110085  NaN
# 2013-01-01 01:50:00  NaN  NaN  NaN  NaN  0.170046 NaN  0.111135  NaN
# 2013-01-01 02:00:00  NaN  NaN  NaN  NaN  0.148056 NaN  0.114267  NaN
# 2013-01-01 02:10:00  NaN  NaN  NaN  NaN  0.120088 NaN  0.117646  NaN
# 2013-01-01 02:20:00  NaN  NaN  NaN  NaN  0.101986 NaN  0.120630  NaN
# 2013-01-01 02:30:00  NaN  NaN  NaN  NaN  0.103005 NaN  0.124090  NaN
# 2013-01-01 02:40:00  NaN  NaN  NaN  NaN  0.113540 NaN  0.127244  NaN
# 2013-01-01 02:50:00  NaN  NaN  NaN  NaN  0.124168 NaN  0.128113  NaN
# 2013-01-01 03:00:00  NaN  NaN  NaN  NaN  0.133576 NaN  0.127550  NaN
# 2013-01-01 03:10:00  NaN  NaN  NaN  NaN  0.142291 NaN  0.127679  NaN
# 2013-01-01 03:20:00  NaN  NaN  NaN  NaN  0.149585 NaN  0.126869  NaN
# 2013-01-01 03:30:00  NaN  NaN  NaN  NaN  0.153477 NaN  0.123125  NaN
# 2013-01-01 03:40:00  NaN  NaN  NaN  NaN  0.155459 NaN  0.119536  NaN
# 2013-01-01 03:50:00  NaN  NaN  NaN  NaN  0.156449 NaN  0.119626  NaN
# 2013-01-01 04:00:00  NaN  NaN  NaN  NaN  0.154974 NaN  0.123268  NaN
# 2013-01-01 04:10:00  NaN  NaN  NaN  NaN  0.152286 NaN  0.128208  NaN
# 2013-01-01 04:20:00  NaN  NaN  NaN  NaN  0.150012 NaN  0.133609  NaN
# 2013-01-01 04:30:00  NaN  NaN  NaN  NaN  0.149298 NaN  0.138517  NaN
# 2013-01-01 04:40:00  NaN  NaN  NaN  NaN  0.150247 NaN  0.140754  NaN
# 2013-01-01 04:50:00  NaN  NaN  NaN  NaN  0.150603 NaN  0.140802  NaN
# ...                  ...  ...  ...  ...       ...  ..       ...  ...
# 2014-12-31 21:00:00  NaN  NaN  NaN  NaN       NaN NaN       NaN  NaN
# 2014-12-31 21:10:00  NaN  NaN  NaN  NaN       NaN NaN       NaN  NaN
# 2014-12-31 21:20:00  NaN  NaN  NaN  NaN       NaN NaN       NaN  NaN
# 2014-12-31 21:30:00  NaN  NaN  NaN  NaN       NaN NaN       NaN  NaN
# 2014-12-31 21:40:00  NaN  NaN  NaN  NaN       NaN NaN       NaN  NaN
# 2014-12-31 21:50:00  NaN  NaN  NaN  NaN       NaN NaN       NaN  NaN
# 2014-12-31 22:00:00  NaN  NaN  NaN  NaN       NaN NaN       NaN  NaN
# 2014-12-31 22:10:00  NaN  NaN  NaN  NaN       NaN NaN       NaN  NaN
# 2014-12-31 22:20:00  NaN  NaN  NaN  NaN       NaN NaN       NaN  NaN
# 2014-12-31 22:30:00  NaN  NaN  NaN  NaN       NaN NaN       NaN  NaN
# 2014-12-31 22:40:00  NaN  NaN  NaN  NaN       NaN NaN       NaN  NaN
# 2014-12-31 22:50:00  NaN  NaN  NaN  NaN       NaN NaN       NaN  NaN
# 2014-12-31 23:00:00  NaN  NaN  NaN  NaN       NaN NaN       NaN  NaN
# 2014-12-31 23:10:00  NaN  NaN  NaN  NaN       NaN NaN       NaN  NaN
# 2014-12-31 23:20:00  NaN  NaN  NaN  NaN       NaN NaN       NaN  NaN
# 2014-12-31 23:30:00  NaN  NaN  NaN  NaN       NaN NaN       NaN  NaN
# 2014-12-31 23:40:00  NaN  NaN  NaN  NaN       NaN NaN       NaN  NaN
# 2014-12-31 23:50:00  NaN  NaN  NaN  NaN       NaN NaN       NaN  NaN
# 2015-01-01 00:00:00  NaN  NaN  NaN  NaN       NaN NaN       NaN  NaN
# 2015-01-01 00:10:00  NaN  NaN  NaN  NaN       NaN NaN       NaN  NaN
# 2015-01-01 00:20:00  NaN  NaN  NaN  NaN       NaN NaN       NaN  NaN
# 2015-01-01 00:30:00  NaN  NaN  NaN  NaN       NaN NaN       NaN  NaN
# 2015-01-01 00:40:00  NaN  NaN  NaN  NaN       NaN NaN       NaN  NaN
# 2015-01-01 00:50:00  NaN  NaN  NaN  NaN       NaN NaN       NaN  NaN
# 2015-01-01 01:00:00  NaN  NaN  NaN  NaN       NaN NaN       NaN  NaN
# 2015-01-01 01:10:00  NaN  NaN  NaN  NaN       NaN NaN       NaN  NaN
# 2015-01-01 01:20:00  NaN  NaN  NaN  NaN       NaN NaN       NaN  NaN
# 2015-01-01 01:30:00  NaN  NaN  NaN  NaN       NaN NaN       NaN  NaN
# 2015-01-01 01:40:00  NaN  NaN  NaN  NaN       NaN NaN       NaN  NaN
# 2015-01-01 01:50:00  NaN  NaN  NaN  NaN       NaN NaN       NaN  NaN
#
#                            24  33 ...   30         4  pvh         6  34  26  \
# 2013-01-01 00:00:00       NaN NaN ...  NaN       NaN  NaN       NaN NaN NaN
# 2013-01-01 00:10:00       NaN NaN ...  NaN       NaN  NaN       NaN NaN NaN
# 2013-01-01 00:20:00       NaN NaN ...  NaN       NaN  NaN       NaN NaN NaN
# 2013-01-01 00:30:00       NaN NaN ...  NaN       NaN  NaN       NaN NaN NaN
# 2013-01-01 00:40:00       NaN NaN ...  NaN       NaN  NaN       NaN NaN NaN
# 2013-01-01 00:50:00       NaN NaN ...  NaN       NaN  NaN       NaN NaN NaN
# 2013-01-01 01:00:00       NaN NaN ...  NaN       NaN  NaN       NaN NaN NaN
# 2013-01-01 01:10:00       NaN NaN ...  NaN       NaN  NaN       NaN NaN NaN
# 2013-01-01 01:20:00       NaN NaN ...  NaN       NaN  NaN       NaN NaN NaN
# 2013-01-01 01:30:00       NaN NaN ...  NaN       NaN  NaN       NaN NaN NaN
# 2013-01-01 01:40:00       NaN NaN ...  NaN       NaN  NaN       NaN NaN NaN
# 2013-01-01 01:50:00       NaN NaN ...  NaN       NaN  NaN       NaN NaN NaN
# 2013-01-01 02:00:00       NaN NaN ...  NaN       NaN  NaN       NaN NaN NaN
# 2013-01-01 02:10:00       NaN NaN ...  NaN       NaN  NaN       NaN NaN NaN
# 2013-01-01 02:20:00       NaN NaN ...  NaN       NaN  NaN       NaN NaN NaN
# 2013-01-01 02:30:00       NaN NaN ...  NaN       NaN  NaN       NaN NaN NaN
# 2013-01-01 02:40:00       NaN NaN ...  NaN  0.056074  NaN  0.092795 NaN NaN
# 2013-01-01 02:50:00       NaN NaN ...  NaN  0.056796  NaN  0.100464 NaN NaN
# 2013-01-01 03:00:00       NaN NaN ...  NaN  0.056917  NaN  0.104971 NaN NaN
# 2013-01-01 03:10:00       NaN NaN ...  NaN  0.057228  NaN  0.105255 NaN NaN
# 2013-01-01 03:20:00       NaN NaN ...  NaN  0.058185  NaN  0.103078 NaN NaN
# 2013-01-01 03:30:00       NaN NaN ...  NaN  0.059453  NaN  0.101701 NaN NaN
# 2013-01-01 03:40:00       NaN NaN ...  NaN  0.060802  NaN  0.102133 NaN NaN
# 2013-01-01 03:50:00       NaN NaN ...  NaN  0.062264  NaN  0.103030 NaN NaN
# 2013-01-01 04:00:00       NaN NaN ...  NaN  0.063227  NaN  0.103329 NaN NaN
# 2013-01-01 04:10:00       NaN NaN ...  NaN  0.063887  NaN  0.102873 NaN NaN
# 2013-01-01 04:20:00       NaN NaN ...  NaN  0.065288  NaN  0.100984 NaN NaN
# 2013-01-01 04:30:00       NaN NaN ...  NaN  0.068021  NaN  0.097269 NaN NaN
# 2013-01-01 04:40:00       NaN NaN ...  NaN  0.072121  NaN  0.093751 NaN NaN
# 2013-01-01 04:50:00       NaN NaN ...  NaN  0.077221  NaN  0.092499 NaN NaN
# ...                       ...  .. ...   ..       ...  ...       ...  ..  ..
# 2014-12-31 21:00:00  0.049509 NaN ...  NaN  0.053059  NaN  0.061001 NaN NaN
# 2014-12-31 21:10:00  0.050095 NaN ...  NaN  0.052557  NaN  0.060779 NaN NaN
# 2014-12-31 21:20:00  0.050218 NaN ...  NaN  0.051648  NaN  0.061406 NaN NaN
# 2014-12-31 21:30:00  0.049963 NaN ...  NaN  0.050716  NaN  0.062415 NaN NaN
# 2014-12-31 21:40:00  0.049419 NaN ...  NaN  0.050263  NaN  0.062944 NaN NaN
# 2014-12-31 21:50:00  0.048851 NaN ...  NaN  0.050253  NaN  0.062873 NaN NaN
# 2014-12-31 22:00:00  0.048595 NaN ...  NaN  0.050552  NaN  0.062410 NaN NaN
# 2014-12-31 22:10:00  0.048534 NaN ...  NaN  0.051231  NaN  0.061620 NaN NaN
# 2014-12-31 22:20:00  0.048256 NaN ...  NaN  0.051938  NaN  0.060436 NaN NaN
# 2014-12-31 22:30:00  0.047567 NaN ...  NaN  0.052107  NaN  0.059277 NaN NaN
# 2014-12-31 22:40:00  0.046705 NaN ...  NaN  0.051589  NaN  0.058678 NaN NaN
# 2014-12-31 22:50:00  0.046187 NaN ...  NaN  0.050775  NaN  0.058343 NaN NaN
# 2014-12-31 23:00:00  0.046085 NaN ...  NaN  0.050001  NaN  0.057961 NaN NaN
# 2014-12-31 23:10:00  0.046215 NaN ...  NaN  0.049203  NaN  0.057623 NaN NaN
# 2014-12-31 23:20:00  0.046619 NaN ...  NaN  0.048493  NaN  0.057381 NaN NaN
# 2014-12-31 23:30:00  0.047151 NaN ...  NaN  0.048178  NaN  0.057233 NaN NaN
# 2014-12-31 23:40:00  0.047338 NaN ...  NaN  0.048145  NaN  0.056973 NaN NaN
# 2014-12-31 23:50:00  0.047137 NaN ...  NaN  0.048020  NaN  0.056526 NaN NaN
# 2015-01-01 00:00:00  0.047054 NaN ...  NaN  0.047683  NaN  0.056167 NaN NaN
# 2015-01-01 00:10:00  0.047877 NaN ...  NaN  0.047555  NaN  0.055872 NaN NaN
# 2015-01-01 00:20:00  0.050388 NaN ...  NaN  0.047909  NaN  0.055365 NaN NaN
# 2015-01-01 00:30:00  0.054915 NaN ...  NaN  0.048572  NaN  0.054482 NaN NaN
# 2015-01-01 00:40:00  0.061830 NaN ...  NaN  0.049200  NaN  0.053456 NaN NaN
# 2015-01-01 00:50:00  0.071018 NaN ...  NaN  0.049319  NaN  0.053100 NaN NaN
# 2015-01-01 01:00:00  0.081369 NaN ...  NaN  0.048965  NaN  0.055445 NaN NaN
# 2015-01-01 01:10:00  0.091490 NaN ...  NaN  0.049532  NaN  0.063959 NaN NaN
# 2015-01-01 01:20:00       NaN NaN ...  NaN       NaN  NaN       NaN NaN NaN
# 2015-01-01 01:30:00       NaN NaN ...  NaN       NaN  NaN       NaN NaN NaN
# 2015-01-01 01:40:00       NaN NaN ...  NaN       NaN  NaN       NaN NaN NaN
# 2015-01-01 01:50:00       NaN NaN ...  NaN       NaN  NaN       NaN NaN NaN
#
#                      sta  sj2  29  tfe
# 2013-01-01 00:00:00  NaN  NaN NaN  NaN
# 2013-01-01 00:10:00  NaN  NaN NaN  NaN
# 2013-01-01 00:20:00  NaN  NaN NaN  NaN
# 2013-01-01 00:30:00  NaN  NaN NaN  NaN
# 2013-01-01 00:40:00  NaN  NaN NaN  NaN
# 2013-01-01 00:50:00  NaN  NaN NaN  NaN
# 2013-01-01 01:00:00  NaN  NaN NaN  NaN
# 2013-01-01 01:10:00  NaN  NaN NaN  NaN
# 2013-01-01 01:20:00  NaN  NaN NaN  NaN
# 2013-01-01 01:30:00  NaN  NaN NaN  NaN
# 2013-01-01 01:40:00  NaN  NaN NaN  NaN
# 2013-01-01 01:50:00  NaN  NaN NaN  NaN
# 2013-01-01 02:00:00  NaN  NaN NaN  NaN
# 2013-01-01 02:10:00  NaN  NaN NaN  NaN
# 2013-01-01 02:20:00  NaN  NaN NaN  NaN
# 2013-01-01 02:30:00  NaN  NaN NaN  NaN
# 2013-01-01 02:40:00  NaN  NaN NaN  NaN
# 2013-01-01 02:50:00  NaN  NaN NaN  NaN
# 2013-01-01 03:00:00  NaN  NaN NaN  NaN
# 2013-01-01 03:10:00  NaN  NaN NaN  NaN
# 2013-01-01 03:20:00  NaN  NaN NaN  NaN
# 2013-01-01 03:30:00  NaN  NaN NaN  NaN
# 2013-01-01 03:40:00  NaN  NaN NaN  NaN
# 2013-01-01 03:50:00  NaN  NaN NaN  NaN
# 2013-01-01 04:00:00  NaN  NaN NaN  NaN
# 2013-01-01 04:10:00  NaN  NaN NaN  NaN
# 2013-01-01 04:20:00  NaN  NaN NaN  NaN
# 2013-01-01 04:30:00  NaN  NaN NaN  NaN
# 2013-01-01 04:40:00  NaN  NaN NaN  NaN
# 2013-01-01 04:50:00  NaN  NaN NaN  NaN
# ...                  ...  ...  ..  ...
# 2014-12-31 21:00:00  NaN  NaN NaN  NaN
# 2014-12-31 21:10:00  NaN  NaN NaN  NaN
# 2014-12-31 21:20:00  NaN  NaN NaN  NaN
# 2014-12-31 21:30:00  NaN  NaN NaN  NaN
# 2014-12-31 21:40:00  NaN  NaN NaN  NaN
# 2014-12-31 21:50:00  NaN  NaN NaN  NaN
# 2014-12-31 22:00:00  NaN  NaN NaN  NaN
# 2014-12-31 22:10:00  NaN  NaN NaN  NaN
# 2014-12-31 22:20:00  NaN  NaN NaN  NaN
# 2014-12-31 22:30:00  NaN  NaN NaN  NaN
# 2014-12-31 22:40:00  NaN  NaN NaN  NaN
# 2014-12-31 22:50:00  NaN  NaN NaN  NaN
# 2014-12-31 23:00:00  NaN  NaN NaN  NaN
# 2014-12-31 23:10:00  NaN  NaN NaN  NaN
# 2014-12-31 23:20:00  NaN  NaN NaN  NaN
# 2014-12-31 23:30:00  NaN  NaN NaN  NaN
# 2014-12-31 23:40:00  NaN  NaN NaN  NaN
# 2014-12-31 23:50:00  NaN  NaN NaN  NaN
# 2015-01-01 00:00:00  NaN  NaN NaN  NaN
# 2015-01-01 00:10:00  NaN  NaN NaN  NaN
# 2015-01-01 00:20:00  NaN  NaN NaN  NaN
# 2015-01-01 00:30:00  NaN  NaN NaN  NaN
# 2015-01-01 00:40:00  NaN  NaN NaN  NaN
# 2015-01-01 00:50:00  NaN  NaN NaN  NaN
# 2015-01-01 01:00:00  NaN  NaN NaN  NaN
# 2015-01-01 01:10:00  NaN  NaN NaN  NaN
# 2015-01-01 01:20:00  NaN  NaN NaN  NaN
# 2015-01-01 01:30:00  NaN  NaN NaN  NaN
# 2015-01-01 01:40:00  NaN  NaN NaN  NaN
# 2015-01-01 01:50:00  NaN  NaN NaN  NaN
#
# [105132 rows x 28 columns]
